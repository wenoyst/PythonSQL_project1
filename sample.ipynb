# %% [markdown]
# # Python SQL project 1

# %%
import matplotlib.pyplot as plt

# %%
# %%sql
# SELECT
#     Track.Name,
#     SUM(InvoiceLine.Quantity) AS TotalSpent
# FROM Track
# JOIN InvoiceLine
#     ON Track.TrackId = InvoiceLine.TrackId
# GROUP BY
#     Track.Name
# ORDER BY
#     TotalSpent DESC
# LIMIT 10;
# Out:
#                         Name  TotalSpent
# 0                The Trooper           5
# 1                   Untitled           4
# 2    The Number Of The Beast           4
# 3        Sure Know Something           4
# 4       Hallowed Be Thy Name           4
# 5                   Eruption           4
# 6          Where Eagles Dare           3
# 7  Welcome Home (Sanitarium)           3
# 8             Sweetest Thing           3
# 9                  Surrender           3

# %%
query1.head()
# Out:
#                       Name  TotalSpent
# 0              The Trooper           5
# 1                 Untitled           4
# 2  The Number Of The Beast           4
# 3      Sure Know Something           4
# 4     Hallowed Be Thy Name           4

# %%
# %%sql
# SELECT
#     Invoice.BillingCountry,
#     SUM(Invoice.Total) AS Total
# FROM Invoice
# GROUP BY
#     Invoice.BillingCountry
# ORDER BY
#     Total DESC
# LIMIT 5;
# Out:
#   BillingCountry   Total
# 0            USA  523.06
# 1         Canada  303.96
# 2         France  195.10
# 3         Brazil  190.10
# 4        Germany  156.48

# %%
# %%sql
# SELECT
#     Employee.FirstName, Employee.LastName,
#     SUM(InvoiceLine.Quantity) AS TotalSell
# FROM Employee
# JOIN Customer ON Customer.SupportRepId = Employee.EmployeeId
#
# JOIN Invoice ON Invoice.CustomerId = Customer.CustomerId
#
# Join InvoiceLine ON InvoiceLine.InvoiceId = Invoice.InvoiceId
#
# GROUP BY
#     Employee.FirstName
# ORDER BY
#     TotalSell DESC
# LIMIT 10;
# Out:
#   FirstName LastName  TotalSell
# 0      Jane  Peacock        796
# 1  Margaret     Park        760
# 2     Steve  Johnson        684

# %%
# Plotting Countries on the bottom (x) and Revenue on the side (y)
query2.plot.bar(x='BillingCountry', y='Total', figsize=(10, 6), color='green')

plt.title('Total Revenue by Country')
plt.xlabel('Country')
plt.ylabel('Revenue ($)')

plt.show()
